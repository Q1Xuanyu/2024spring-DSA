# %%
# Accepted

import math

# 使用Sieve of Eratosthenes算法生成素数表
def Generate_prime(limit):
    primes = [True] * (limit + 1)
    primes[0] = primes[1] = False
    for i in range(2, int(math.sqrt(limit)) + 1):
        if primes[i]:
            for j in range(i * i, limit + 1, i):
                primes[j] = False
    return primes

def T_prime(n,prime):
    if n**0.5==int(n**0.5):
        return prime[int(n**0.5)]
    else:
        return 0

prime=Generate_prime(10**4)
        
m,n=map(int,input().split())

for i in range(m):
    score=list(map(int,input().split()))
    Score=0
    for j in score:
        if T_prime(j,prime):
            Score+=j
    if Score==0:
        print(0)
    else:
        print(f'{Score/len(score):.2f}')

# %%
# Time Limit Exceeded

def Prime(n):
    check=1
    for i in range(2,int(n**0.5)+1):
        if n%i==0:
            check=0
    return check

def T_prime(n,prime):
    if n**0.5==int(n**0.5):
        return prime[int(n**0.5)]
    else:
        return 0

prime=[False]*(10**4+1)
for i in range(2,10**4+1):
    if Prime(i):
        prime[i]=True
        
m,n=map(int,input().split())

for i in range(m):
    score=list(map(int,input().split()))
    Score=0
    for j in score:
        if T_prime(j,prime):
            Score+=j
    if Score==0:
        print(0)
    else:
        print(f'{Score/len(score):.2f}')
# Out:
# 0
# 1.33
# 14.50

# %%
# Chatgpt
# Time Limit Exceeded
import math

# 判断一个数是否为素数
def is_prime(n):
    if n <= 1:
        return False
    if n <= 3:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False
    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True

# 计算t-prime
def is_t_prime(n):
    root = int(math.sqrt(n))
    if is_prime(root) and root * root == n:
        return True
    return False

# 输入学生人数和课程数
m, n = map(int, input().split())

# 逐个学生处理
for _ in range(m):
    scores = list(map(int, input().split()))
    total_score = 0
    valid_count = 0
    # 遍历学生的每门课成绩
    for score in scores:
        if is_t_prime(score):
            total_score += score
            valid_count += 1
    # 计算平均分，保留两位小数
    if valid_count == 0:
        print("0")
    else:
        average_score = total_score / len(scores)
        print("{:.2f}".format(average_score))
# Out:
# 0
# 1.33
# 14.50

# %%
# Chatgpt
# Accepted
import math

# 使用Sieve of Eratosthenes算法生成素数表
def generate_primes(limit):
    primes = [True] * (limit + 1)
    primes[0] = primes[1] = False
    for i in range(2, int(math.sqrt(limit)) + 1):
        if primes[i]:
            for j in range(i * i, limit + 1, i):
                primes[j] = False
    return primes

# 判断一个数是否为t-prime
def is_t_prime(n, primes):
    root = int(math.sqrt(n))
    if n <= 1 or root * root != n:
        return False
    return primes[root]

# 输入学生人数和课程数
m, n = map(int, input().split())

# 生成素数表
limit = int(math.sqrt(10**8))
primes = generate_primes(limit)

# 逐个学生处理
for _ in range(m):
    scores = list(map(int, input().split()))
    total_score = 0
    valid_count = 0
    # 遍历学生的每门课成绩
    for score in scores:
        if is_t_prime(score, primes):
            total_score += score
            valid_count += 1
    # 计算平均分，保留两位小数
    if valid_count == 0:
        print("0")
    else:
        average_score = total_score / len(scores)
        print("{:.2f}".format(average_score))
# Out:
# 0
# 1.33
# 14.50
